# %% [markdown]
# # Limpeza de Dados do Dataset das Corridas

# %%
# Import das bibliotecas

import pandas as pd

# %%
# Lendo o arquivo csv
df = pd.read_csv('../data/races.csv', na_values=["\\N"])
df.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...      NaN
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...      NaN
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...      NaN
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...      NaN
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...      NaN
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# 0      NaN      NaN      NaN      NaN      NaN        NaN        NaN
# 1      NaN      NaN      NaN      NaN      NaN        NaN        NaN
# 2      NaN      NaN      NaN      NaN      NaN        NaN        NaN
# 3      NaN      NaN      NaN      NaN      NaN        NaN        NaN
# 4      NaN      NaN      NaN      NaN      NaN        NaN        NaN
#
#   sprint_date sprint_time
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df.dtypes
# Out:
# raceId          int64
# year            int64
# round           int64
# circuitId       int64
# name           object
# date           object
# time           object
# url            object
# fp1_date       object
# fp1_time       object
# fp2_date       object
# fp2_time       object
# fp3_date       object
# fp3_time       object
# quali_date     object
# quali_time     object
# sprint_date    object
# sprint_time    object
# dtype: object

# %% [markdown]
# Há uma inconsistência de tipo de dados nas colunas de datas (`date`, `fp1_date`, `fp2_date`, `fp3_date`, `quali_date` e `sprint_date`). Essas colunas estão definidas como `object`, mas representam datas (`datetime64[ns]`).
#
# As colunas que representam valores de tempo também estão definidas como `object`, porém não há nenhum tipo de dados em Python que representem o tempo no formato `%H:%M:%S`. No entanto, ao realizar o upload dos arquivos CSV na plataforma do BigQuery os dados serão reconhecidos corretamente como tipo `time`.

# %%
# Corrigindo o tipo de dados das colunas representar datas
df['date'] = pd.to_datetime(df['date'])
df['fp1_date'] = pd.to_datetime(df['fp1_date'])
df['fp2_date'] = pd.to_datetime(df['fp2_date'])
df['fp3_date'] = pd.to_datetime(df['fp3_date'])
df['quali_date'] = pd.to_datetime(df['quali_date'])
df['sprint_date'] = pd.to_datetime(df['sprint_date'])
df.head()
# Out:
#    raceId  year  round  circuitId                   name       date      time  \
# 0       1  2009      1          1  Australian Grand Prix 2009-03-29  06:00:00
# 1       2  2009      2          2   Malaysian Grand Prix 2009-04-05  09:00:00
# 2       3  2009      3         17     Chinese Grand Prix 2009-04-19  07:00:00
# 3       4  2009      4          3     Bahrain Grand Prix 2009-04-26  12:00:00
# 4       5  2009      5          4     Spanish Grand Prix 2009-05-10  12:00:00
#
#                                                  url fp1_date fp1_time  \
# 0  http://en.wikipedia.org/wiki/2009_Australian_G...      NaT      NaN
# 1  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...      NaT      NaN
# 2  http://en.wikipedia.org/wiki/2009_Chinese_Gran...      NaT      NaN
# 3  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...      NaT      NaN
# 4  http://en.wikipedia.org/wiki/2009_Spanish_Gran...      NaT      NaN
#
#   fp2_date fp2_time fp3_date fp3_time quali_date quali_time sprint_date  \
# 0      NaT      NaN      NaT      NaN        NaT        NaN         NaT
# 1      NaT      NaN      NaT      NaN        NaT        NaN         NaT
# 2      NaT      NaN      NaT      NaN        NaT        NaN         NaT
# 3      NaT      NaN      NaT      NaN        NaT        NaN         NaT
# 4      NaT      NaN      NaT      NaN        NaT        NaN         NaT
#
#   sprint_time
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.dtypes
# Out:
# raceId                  int64
# year                    int64
# round                   int64
# circuitId               int64
# name                   object
# date           datetime64[ns]
# time                   object
# url                    object
# fp1_date       datetime64[ns]
# fp1_time               object
# fp2_date       datetime64[ns]
# fp2_time               object
# fp3_date       datetime64[ns]
# fp3_time               object
# quali_date     datetime64[ns]
# quali_time             object
# sprint_date    datetime64[ns]
# sprint_time            object
# dtype: object

# %% [markdown]
# A inconsistência nos tipos das colunas foi corrigida.

# %% [markdown]
# ## Identificando Dados Ausentes

# %%
# Verificando valores ausentes
df.isnull().sum()
# Out:
# raceId            0
# year              0
# round             0
# circuitId         0
# name              0
# date              0
# time            731
# url               0
# fp1_date       1035
# fp1_time       1057
# fp2_date       1035
# fp2_time       1057
# 1050       NaN 2021-09-11       NaN      NaT      NaN 2021-09-10        NaN
# 1055       NaN 2021-11-13       NaN      NaT      NaN 2021-11-12        NaN
# 1060  11:30:00 2022-04-23  10:30:00      NaT      NaN 2022-04-22   15:00:00
# 1067  11:30:00 2022-07-09  10:30:00      NaT      NaN 2022-07-08   15:00:00
# 1077  15:30:00 2022-11-12  15:30:00      NaT      NaN 2022-11-11   19:00:00
# 1082  09:30:00 2023-04-29  09:30:00      NaT      NaN 2023-04-28   13:00:00
# 1087  11:30:00 2023-07-01  10:30:00      NaT      NaN 2023-06-30   15:00:00
# 1090  11:30:00 2023-07-29  10:30:00      NaT      NaN 2023-07-28   15:00:00
# 1095  13:30:00 2023-10-07  13:00:00      NaT      NaN 2023-10-06   17:00:00
# 1096  17:30:00 2023-10-21  18:00:00      NaT      NaN 2023-10-20   21:00:00
# 1098  14:30:00 2023-11-04  14:30:00      NaT      NaN 2023-11-03   18:00:00
# 1105  03:30:00 2024-04-19  07:30:00      NaT      NaN 2024-04-20   07:00:00
# 1106  16:30:00 2024-05-03  20:30:00      NaT      NaN 2024-05-04   20:00:00
# 1111  10:30:00 2024-06-28  14:30:00      NaT      NaN 2024-06-29   14:00:00
# 1119  17:30:00 2024-10-18  21:30:00      NaT      NaN 2024-10-19   22:00:00
# 1121  14:30:00 2024-11-01  18:30:00      NaT      NaN 2024-11-02   18:00:00
# 1123  13:30:00 2024-11-29  17:30:00      NaT      NaN 2024-11-30   17:00:00
#
#      sprint_date sprint_time
# 1046  2021-07-17         NaN
# 1050  2021-09-11         NaN
# 1055  2021-11-13         NaN
# 1060  2022-04-23    14:30:00
# 1067  2022-07-09    14:30:00
# 1077  2022-11-12    19:30:00
# 1082  2023-04-29    13:30:00
# 1087  2023-07-01    14:30:00
# 1090  2023-07-29    14:30:00
# 1095  2023-10-07    17:30:00
# 1096  2023-10-21    22:00:00
# 1098  2023-11-04    18:30:00
# 1105  2024-04-20    03:00:00
# 1106  2024-05-04    16:00:00
# 1111  2024-06-29    10:00:00
# 1119  2024-10-19    18:00:00
# 1121  2024-11-02    14:00:00
# 1123  2024-11-30    13:00:00

# %% [markdown]
# ## Identificando Dados Duplicados

# %%
# Verificação de registros duplicados
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [raceId, year, round, circuitId, name, date, time, url, fp1_date, fp1_time, fp2_date, fp2_time, fp3_date, fp3_time, quali_date, quali_time, sprint_date, sprint_time]
# Index: []

# %%
# Verificação de registros duplicados apenas na coluna 'raceId'
df[df.duplicated(subset='raceId' ,keep=False)]
# Out:
# Empty DataFrame
# Columns: [raceId, year, round, circuitId, name, date, time, url, fp1_date, fp1_time, fp2_date, fp2_time, fp3_date, fp3_time, quali_date, quali_time, sprint_date, sprint_time]
# Index: []

# %% [markdown]
# Não foi encontrado nenhum registro duplicado.

# %% [markdown]
# ## Análise Descritiva das Variáveis Numéricas

# %%
# Resumo estatístico das variáveis numéricas
df.describe()
# Out:
#             raceId         year        round    circuitId
# count  1125.000000  1125.000000  1125.000000  1125.000000
# mean    565.710222  1992.703111     8.579556    23.889778
# std     328.813817    20.603848     5.159910    19.633527
# min       1.000000  1950.000000     1.000000     1.000000
# 25%     282.000000  1977.000000     4.000000     9.000000
# 50%     563.000000  1994.000000     8.000000    18.000000
# 75%     845.000000  2011.000000    13.000000    34.000000
# max    1144.000000  2024.000000    24.000000    80.000000

# %% [markdown]
# Observando a análise estatística acima não foram identificadas inconsistências em nenhuma variável.

# %% [markdown]
# ## Salvando o Dataset Tratado

# %%
df.to_csv('../data_cleaned/races.csv', index=False)
